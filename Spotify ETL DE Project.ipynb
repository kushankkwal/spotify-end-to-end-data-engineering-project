# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "cd950945d103464faa9ec2c5a8b9f8f3", client_secret = "56fde508ec894e75a934e50434e54e90")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=1586c2ede2dc4823"

# %%
#using the split function we can split the link and it gets converted into one final list. 
playlist_link.split("/")
# Out:
# ['https:',
#  '',
#  'open.spotify.com',
#  'playlist',
#  '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=1586c2ede2dc4823']

# %%
#now we want only the playlist id, for that we can use indexing. 
playlist_link.split("/")[-1]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=1586c2ede2dc4823'

# %%
playlist_link.split("/")[-1].split("?")
# Out:
# ['37i9dQZEVXbNG2KDcFcKOF', 'si=1333723a6eff4b7f&nd=1&dlsi=1586c2ede2dc4823']

# %%
playlist_URI = playlist_link.split("/")[-1].split("?")[0]

# %%
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
#This will give us the JSON data. 
#we will be storing the data into a variable. 
data = sp.playlist_tracks(playlist_URI)
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-01-26T16:09:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#        'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#        'id': '3Me35AWHCGqW4sZ7bWWJt1',
#        'name': 'Xavi',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
#now we will start extracting and transform this data into proper structure. 
#we have information about the Ablum, Tracks & Artist. 
#we will create 3 different tables to understand. we will do the transformation job. 

data['items']
# Out:
# [{'added_at': '2024-01-26T16:09:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#       'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#       'id': '3Me35AWHCGqW4sZ7bWWJt1',
#       'name': 'Xavi',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
#we will extract album information. 
data['items'][0] #........we have extracted the information for 1st track.
# Out:
# {'added_at': '2024-01-26T16:09:07Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#      'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#      'id': '3Me35AWHCGqW4sZ7bWWJt1',
#      'name': 'Xavi',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
data['items'][0]['track'] #.........we have extracted the information about the track.
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#     'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#     'id': '3Me35AWHCGqW4sZ7bWWJt1',
#     'name': 'Xavi',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
data['items'][0]['track']['album'] #.......we have extracted information about album.
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#    'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#    'id': '3Me35AWHCGqW4sZ7bWWJt1',
#    'name': 'Xavi',
#    'type': 'artist',
#    'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
data['items'][0]['track']['album']['id']  #......we have extracted the album_id
# Out:
# '2IoSjweCu07y9mv5H1Cj3v'

# %%
data['items'][0]['track']['album']['name'] #album name
# Out:
# 'La Diabla'

# %%
data['items'][0]['track']['album']['release_date'] #release date
# Out:
# '2023-11-30'

# %%
data['items'][0]['track']['album']['total_tracks'] #total tracks
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify'] #album_url
# Out:
# 'https://open.spotify.com/album/2IoSjweCu07y9mv5H1Cj3v'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    #print(album_name)
    #we have to convert the ouotput into dictionary, so we can create DataFrame oout of it. 
    album_element = {'album_id' : album_id,
                    'name' : album_name,
                    'release_date' : album_release_date,
                    'total_tracks' : album_total_tracks,
                    'url' : album_url}
    #print(album_element)
    album_list.append(album_element)
#we have structured the data for the ablum, we can do it for the tracks.

# %%
album_list
# Out:
# [{'album_id': '2IoSjweCu07y9mv5H1Cj3v',
#   'name': 'La Diabla',
#   'release_date': '2023-11-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2IoSjweCu07y9mv5H1Cj3v'},
#  {'album_id': '2B9amdrHDIKOoEiPUfZGtb',
#   'name': 'yes, and?',
#   'release_date': '2024-01-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2B9amdrHDIKOoEiPUfZGtb'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '6VCO0fDBGbRW8mCEvV95af',
#   'name': 'Lovin On Me',
#   'release_date': '2023-11-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6VCO0fDBGbRW8mCEvV95af'},
#  {'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'name': 'The Idol Episode 4 (Music from the HBO Original Series)',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
# ...

# %%
#we have structured the data for the ablum, we can do it for the tracks. 
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#     'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#     'id': '3Me35AWHCGqW4sZ7bWWJt1',
#     'name': 'Xavi',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
data['items'][0]['track']['artists'] #as 1 track have many artist.
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#   'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#   'id': '3Me35AWHCGqW4sZ7bWWJt1',
#   'name': 'Xavi',
#   'type': 'artist',
#   'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}]

# %%
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            print(value['artists']) #the put is that we are getting dictionary in list.
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'}, 'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1', 'id': '3Me35AWHCGqW4sZ7bWWJt1', 'name': 'Xavi', 'type': 'artist', 'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'}, 'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR', 'id': '66CXWjxzNUsdJxJ2JdwvnR', 'name': 'Ariana Grande', 'type': 'artist', 'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'}, 'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym', 'id': '45dkTj5sMRSjrmBSBeiHym', 'name': 'Tate McRae', 'type': 'artist', 'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}]
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']: #this for loop will provide us the output in dictionary.
                print(artist['id'])
# Out:
# 3Me35AWHCGqW4sZ7bWWJt1
# 66CXWjxzNUsdJxJ2JdwvnR
# 45dkTj5sMRSjrmBSBeiHym
# 2LIk90788K0zvyj2JJVwkJ
# 1Xyo4u8uXC1ZmMpatF05PJ
# 250b0Wlc5Vk0CoUsaCY84M
# 1pBLC0qVRTB5zVMuteQ9jJ
# 2uYWxilOVlUdk4oV9DvwqK
# 06HL4z0CvFAxyc27GXpf02
# 2RQXRUsr4IW1f3mKyKsy4B
# 1URnnhqYAYcrqrcwql10ft
# 2LRoIwlKmHjgvigdNGBHNo
# 7jAs1uPnpfNmT6e5qtEPxq
# 1U1el3k54VvEUzo3ybLPlM
# 12GqGscKJx3aE4t07u7eVZ
# 3Me35AWHCGqW4sZ7bWWJt1
# 2cBh5lVMg222FFuRU7EfDE
# 1Xyo4u8uXC1ZmMpatF05PJ
# 699OTQXzgjhIYAHMy9RyPD
# 6tbjWDEIzxoDsBA1FuhfPW
# 716NhGYqD1jl2wI1Qkgq36
# 3qsKSpcV3ncke3hw52JSMB
# 12GqGscKJx3aE4t07u7eVZ
# 7FNnA9vBm6EKceENgCGRMb
# 33qOK5uJ8AR2xuQQAhHump
# 7Ln80lUS6He07XvHI8qqHH
# 4q3ewBCX7sLwd24euuV69X
# 2LRoIwlKmHjgvigdNGBHNo
# 7uMDnSZyUYNBPLhPMNuaM2
# 5cj0lLjcoR7YOSnhnX0Po5
# 6HaGTQPmzraVmaVxvz6EUc
# 3MdXrJWsbVzdn6fe5JYkSQ
# 790FomKkXshlbRYZFtlgla
# 12GqGscKJx3aE4t07u7eVZ
# 22wbnEMDvgVIAGdFeek6ET
# 3SozjO3Lat463tQICI9LcE
# 1Xyo4u8uXC1ZmMpatF05PJ
# 4tZwfgrHOc3mvqYlEYSvVi
# 6M2wZ9GZgrQXHCFfjv46we
# 6dLuQ5qXxIuWc5urxfIiZR
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']: #this for loop will provide us the output in dictionary.
                artist_dict = {'artist_id' : artist['id'],
                'artist_name' : artist['name'],
                'external_url' : artist['href'],
                }
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3Me35AWHCGqW4sZ7bWWJt1',
#   'artist_name': 'Xavi',
#   'external_url': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '2LIk90788K0zvyj2JJVwkJ',
#   'artist_name': 'Jack Harlow',
#   'external_url': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'external_url': 'https://api.spotify.com/v1/artists/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '1pBLC0qVRTB5zVMuteQ9jJ',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0R6NfOiLzLj4O5VbYSJAjf',
#   'song_name': 'La Diabla',
#   'duration_ms': 172264,
#   'url': 'https://open.spotify.com/track/0R6NfOiLzLj4O5VbYSJAjf',
#   'popularity': 99,
#   'song_added': '2024-01-26T16:09:07Z',
#   'album_id': '2IoSjweCu07y9mv5H1Cj3v',
#   'artist_id': '3Me35AWHCGqW4sZ7bWWJt1'},
#  {'song_id': '7gaA3wERFkFkgivjwbSvkG',
#   'song_name': 'yes, and?',
#   'duration_ms': 214994,
#   'url': 'https://open.spotify.com/track/7gaA3wERFkFkgivjwbSvkG',
#   'popularity': 97,
#   'song_added': '2024-01-26T16:09:07Z',
#   'album_id': '2B9amdrHDIKOoEiPUfZGtb',
#   'artist_id': '66CXWjxzNUsdJxJ2JdwvnR'},
#  {'song_id': '3rUGC1vUpkDG9CZFHMur1t',
#   'song_name': 'greedy',
#   'duration_ms': 131872,
#   'url': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t',
#   'popularity': 100,
#   'song_added': '2024-01-26T16:09:07Z',
#   'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '4xhsWYTOGcal8zt0J161CU',
# ...

# %%
#creating Data Frames for transforming the data.
import pandas as pd

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2IoSjweCu07y9mv5H1Cj3v                                          La Diabla
# 1  2B9amdrHDIKOoEiPUfZGtb                                          yes, and?
# 2  3UOV8XvCwMKaATRNXrYCjN                                             greedy
# 3  6VCO0fDBGbRW8mCEvV95af                                        Lovin On Me
# 4  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
#
#   release_date  total_tracks  \
# 0   2023-11-30             1
# 1   2024-01-12             1
# 2   2023-09-15             1
# 3   2023-11-10             1
# 4   2023-06-23             3
#
#                                                  url
# 0  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 1  https://open.spotify.com/album/2B9amdrHDIKOoEi...
# 2  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 3  https://open.spotify.com/album/6VCO0fDBGbRW8mC...
# 4  https://open.spotify.com/album/7tzVd1fwkxsoryt...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
#as we need to drop the duplicates. 
album_df = album_df.drop_duplicates(subset = ['album_id'])
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2IoSjweCu07y9mv5H1Cj3v                                          La Diabla
# 1  2B9amdrHDIKOoEiPUfZGtb                                          yes, and?
# 2  3UOV8XvCwMKaATRNXrYCjN                                             greedy
# 3  6VCO0fDBGbRW8mCEvV95af                                        Lovin On Me
# 4  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
#
#   release_date  total_tracks  \
# 0   2023-11-30             1
# 1   2024-01-12             1
# 2   2023-09-15             1
# 3   2023-11-10             1
# 4   2023-06-23             3
#
#                                                  url
# 0  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 1  https://open.spotify.com/album/2B9amdrHDIKOoEi...
# 2  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 3  https://open.spotify.com/album/6VCO0fDBGbRW8mC...
# 4  https://open.spotify.com/album/7tzVd1fwkxsoryt...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id    artist_name  \
# 0   3Me35AWHCGqW4sZ7bWWJt1           Xavi
# 1   66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
# 2   45dkTj5sMRSjrmBSBeiHym     Tate McRae
# 3   2LIk90788K0zvyj2JJVwkJ    Jack Harlow
# 4   1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# ..                     ...            ...
# 70  1URnnhqYAYcrqrcwql10ft      21 Savage
# 71  0Y5tJX1MQlPlqiwlOH1tJY   Travis Scott
# 72  0iEtIxbK0KxaSlF7G42ZOp   Metro Boomin
# 73  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 74  5YGY8feqx7naU7z4HrwZM6    Miley Cyrus
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/3Me35AWHCGq...
# 1   https://api.spotify.com/v1/artists/66CXWjxzNUs...
# 2   https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3   https://api.spotify.com/v1/artists/2LIk90788K0...
# 4   https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# ..                                                ...
# 70  https://api.spotify.com/v1/artists/1URnnhqYAYc...
# ...

# %%
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])
artist_df
# Out:
#                  artist_id    artist_name  \
# 0   3Me35AWHCGqW4sZ7bWWJt1           Xavi
# 1   66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
# 2   45dkTj5sMRSjrmBSBeiHym     Tate McRae
# 3   2LIk90788K0zvyj2JJVwkJ    Jack Harlow
# 4   1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# ..                     ...            ...
# 68  1r4hJ1h58CWwUQe3MxPuau         Maluma
# 69  66ihevNkSYNzRAl44dx6jJ     Carin Leon
# 71  0Y5tJX1MQlPlqiwlOH1tJY   Travis Scott
# 72  0iEtIxbK0KxaSlF7G42ZOp   Metro Boomin
# 74  5YGY8feqx7naU7z4HrwZM6    Miley Cyrus
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/3Me35AWHCGq...
# 1   https://api.spotify.com/v1/artists/66CXWjxzNUs...
# 2   https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3   https://api.spotify.com/v1/artists/2LIk90788K0...
# 4   https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# ..                                                ...
# 68  https://api.spotify.com/v1/artists/1r4hJ1h58CW...
# ...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 74
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     62 non-null     object
#  1   artist_name   62 non-null     object
#  2   external_url  62 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   0R6NfOiLzLj4O5VbYSJAjf                                          La Diabla
# 1   7gaA3wERFkFkgivjwbSvkG                                          yes, and?
# 2   3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 3   4xhsWYTOGcal8zt0J161CU                                        Lovin On Me
# 4   7CyPwkp0oE8Ro9Dd5CUDjW     One Of The Girls (with JENNIE, Lily Rose Depp)
# 5   3vkCueOmm7xQDoJ17W1Pm3                              My Love Mine All Mine
# 6   1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 7   0mflMxspEfB0VbI1kyLiAv                                       Stick Season
# 8   52eIcoLUM25zbQupAZYoFh                                             redrum
# 9   7bywjHOc0wSjGGbj04XbVi                                               LUNA
# 10  6XaJfhwof7qIgbbXO5tIQI               Igual Que Un Ángel (with Peso Pluma)
# ...

# %%
song_df = song_df.drop_duplicates(subset = ['song_id'])
song_df
# Out:
#                    song_id                                          song_name  \
# 0   0R6NfOiLzLj4O5VbYSJAjf                                          La Diabla
# 1   7gaA3wERFkFkgivjwbSvkG                                          yes, and?
# 2   3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 3   4xhsWYTOGcal8zt0J161CU                                        Lovin On Me
# 4   7CyPwkp0oE8Ro9Dd5CUDjW     One Of The Girls (with JENNIE, Lily Rose Depp)
# 5   3vkCueOmm7xQDoJ17W1Pm3                              My Love Mine All Mine
# 6   1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 7   0mflMxspEfB0VbI1kyLiAv                                       Stick Season
# 8   52eIcoLUM25zbQupAZYoFh                                             redrum
# 9   7bywjHOc0wSjGGbj04XbVi                                               LUNA
# 10  6XaJfhwof7qIgbbXO5tIQI               Igual Que Un Ángel (with Peso Pluma)
# ...

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2IoSjweCu07y9mv5H1Cj3v                                          La Diabla
# 1  2B9amdrHDIKOoEiPUfZGtb                                          yes, and?
# 2  3UOV8XvCwMKaATRNXrYCjN                                             greedy
# 3  6VCO0fDBGbRW8mCEvV95af                                        Lovin On Me
# 4  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
#
#   release_date  total_tracks  \
# 0   2023-11-30             1
# 1   2024-01-12             1
# 2   2023-09-15             1
# 3   2023-11-10             1
# 4   2023-06-23             3
#
#                                                  url
# 0  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 1  https://open.spotify.com/album/2B9amdrHDIKOoEi...
# 2  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 3  https://open.spotify.com/album/6VCO0fDBGbRW8mC...
# 4  https://open.spotify.com/album/7tzVd1fwkxsoryt...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  3Me35AWHCGqW4sZ7bWWJt1           Xavi
# 1  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
# 2  45dkTj5sMRSjrmBSBeiHym     Tate McRae
# 3  2LIk90788K0zvyj2JJVwkJ    Jack Harlow
# 4  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3Me35AWHCGq...
# 1  https://api.spotify.com/v1/artists/66CXWjxzNUs...
# 2  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3  https://api.spotify.com/v1/artists/2LIk90788K0...
# 4  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...

# %%
song_df.head()
# Out:
#                   song_id                                       song_name  \
# 0  0R6NfOiLzLj4O5VbYSJAjf                                       La Diabla
# 1  7gaA3wERFkFkgivjwbSvkG                                       yes, and?
# 2  3rUGC1vUpkDG9CZFHMur1t                                          greedy
# 3  4xhsWYTOGcal8zt0J161CU                                     Lovin On Me
# 4  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
#
#    duration_ms                                                url  popularity  \
# 0       172264  https://open.spotify.com/track/0R6NfOiLzLj4O5V...          99
# 1       214994  https://open.spotify.com/track/7gaA3wERFkFkgiv...          97
# 2       131872  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...         100
# 3       138411  https://open.spotify.com/track/4xhsWYTOGcal8zt...          99
# 4       244684  https://open.spotify.com/track/7CyPwkp0oE8Ro9D...          98
#
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      47 non-null     object
#  1   name          47 non-null     object
#  2   release_date  47 non-null     datetime64[ns]
#  3   total_tracks  47 non-null     int64
#  4   url           47 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.5+ KB

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2IoSjweCu07y9mv5H1Cj3v                                          La Diabla
# 1  2B9amdrHDIKOoEiPUfZGtb                                          yes, and?
# 2  3UOV8XvCwMKaATRNXrYCjN                                             greedy
# 3  6VCO0fDBGbRW8mCEvV95af                                        Lovin On Me
# 4  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
#
#   release_date  total_tracks  \
# 0   2023-11-30             1
# 1   2024-01-12             1
# 2   2023-09-15             1
# 3   2023-11-10             1
# 4   2023-06-23             3
#
#                                                  url
# 0  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 1  https://open.spotify.com/album/2B9amdrHDIKOoEi...
# 2  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 3  https://open.spotify.com/album/6VCO0fDBGbRW8mC...
# 4  https://open.spotify.com/album/7tzVd1fwkxsoryt...

# %%
song_df.head()
# Out:
#                   song_id                                       song_name  \
# 0  0R6NfOiLzLj4O5VbYSJAjf                                       La Diabla
# 1  7gaA3wERFkFkgivjwbSvkG                                       yes, and?
# 2  3rUGC1vUpkDG9CZFHMur1t                                          greedy
# 3  4xhsWYTOGcal8zt0J161CU                                     Lovin On Me
# 4  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
#
#    duration_ms                                                url  popularity  \
# 0       172264  https://open.spotify.com/track/0R6NfOiLzLj4O5V...          99
# 1       214994  https://open.spotify.com/track/7gaA3wERFkFkgiv...          97
# 2       131872  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...         100
# 3       138411  https://open.spotify.com/track/4xhsWYTOGcal8zt...          99
# 4       244684  https://open.spotify.com/track/7CyPwkp0oE8Ro9D...          98
#
# ...
